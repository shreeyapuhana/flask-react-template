# %% [markdown]
# <a href="https://colab.research.google.com/github/shreeyapuhana/flask-react-template/blob/master/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "puhanashreeya@gmail.com"
# !git config --global user.name "shreeyapuhana"

# %%
# !git clone https://github.com/bettrhq-assessments/flask-react-assessment-shreeyapuhana.git
# %cd flask-react-assessment-shreeyapuhana
# Out:
# Cloning into 'flask-react-assessment-shreeyapuhana'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'flask-react-assessment-shreeyapuhana'
# /content
